# %%
import pandas as pd
import numpy as np
import datetime as df

# %%
flood_2010s = pd.read_csv("floods_data/flood2010s.csv")
flood_2016s = pd.read_csv("floods_data/floods2016.csv")
flood_2018s = pd.read_csv("floods_data/floods2018.csv")
flood_2000s = pd.read_csv("floods_data/floods_2000s.csv")

# %%
flood_2000s.head()
# Out:
#    episode_id  event_id          state  state_fips_code event_type cz_type  \
# 0     1115005   5245462  West virginia               54      flood       C
# 1     1115595   5248631       Oklahoma               40      flood       C
# 2     1115660   5249528           Iowa               19      flood       C
# 3     1115660   5249522           Iowa               19      flood       C
# 4     1115660   5249523           Iowa               19      flood       C
#
#    cz_fips_code   cz_name  wfo     event_begin_time  ... tor_length tor_width  \
# 0            45     LOGAN  RLX  2001-05-18 10:00:00  ...        NaN       NaN
# 1           109  OKLAHOMA  OUN  2001-05-30 01:15:00  ...        NaN       NaN
# 2            11    BENTON  DVN  2001-05-10 18:33:00  ...        NaN       NaN
# 3           113      LINN  DVN  2001-05-10 18:15:00  ...        NaN       NaN
# 4            11    BENTON  DVN  2001-05-10 18:17:00  ...        NaN       NaN
#
# ...

# %%
flood_data = flood_2010s.append(flood_2016s, ignore_index = True)

# %%
flood_data = flood_data.append(flood_2018s, ignore_index = True)

# %%
flood_data = flood_data.append(flood_2000s, ignore_index = True)

# %%
flood_data.head()
# Out:
#    episode_id  event_id       state  state_fips_code event_type cz_type  \
# 0       59076    360902    Delaware               10      flood       C
# 1       59077    360909  New jersey               34      flood       C
# 2       59077    360914  New jersey               34      flood       C
# 3       59155    357685     Indiana               18      flood       C
# 4       59379    355469     Alabama                1      flood       C
#
#    cz_fips_code     cz_name  wfo     event_begin_time  ... tor_length  \
# 0             3  NEW CASTLE  PHI  2012-01-12 05:50:00  ...        NaN
# 1            35    SOMERSET  PHI  2012-01-12 10:27:00  ...        NaN
# 2            35    SOMERSET  PHI  2012-01-12 11:50:00  ...        NaN
# 3            77   JEFFERSON  LMK  2012-01-17 23:45:00  ...        NaN
# 4            95    MARSHALL  HUN  2012-01-26 19:00:00  ...        NaN
#
#   tor_width  tor_other_wfo  location_index  event_range  event_azimuth  \
# ...

# %%
flood_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34586 entries, 0 to 34585
# Data columns (total 33 columns):
# episode_id            34586 non-null int64
# event_id              34586 non-null int64
# state                 34586 non-null object
# state_fips_code       34586 non-null int64
# event_type            34586 non-null object
# cz_type               34586 non-null object
# cz_fips_code          34586 non-null int64
# cz_name               34586 non-null object
# wfo                   34586 non-null object
# event_begin_time      34586 non-null object
# event_timezone        34586 non-null object
# event_end_time        34586 non-null object
# injuries_direct       34586 non-null int64
# injuries_indirect     34586 non-null int64
# deaths_direct         34586 non-null int64
# deaths_indirect       34586 non-null int64
# damage_property       33519 non-null float64
# damage_crops          33053 non-null float64
# source                34586 non-null object
# ...

# %%
flood_data = flood_data.loc[: ,["episode_id","state","event_type","event_begin_time","event_end_time","event_timezone","damage_property","event_latitude","event_longitude","cz_type","cz_fips_code","damage_crops","source"]]

# %%
flood_data.head()
# Out:
#    episode_id       state event_type     event_begin_time  \
# 0       59076    Delaware      flood  2012-01-12 05:50:00
# 1       59077  New jersey      flood  2012-01-12 10:27:00
# 2       59077  New jersey      flood  2012-01-12 11:50:00
# 3       59155     Indiana      flood  2012-01-17 23:45:00
# 4       59379     Alabama      flood  2012-01-26 19:00:00
#
#         event_end_time event_timezone  damage_property  event_latitude  \
# 0  2012-01-12 11:34:00          EST-5              0.0         39.6300
# 1  2012-01-12 15:34:00          EST-5              0.0         40.5643
# 2  2012-01-13 20:07:00          EST-5              0.0         40.4472
# 3  2012-01-18 03:15:00          EST-5              0.0         38.8029
# 4  2012-01-26 23:00:00          CST-6           5000.0         34.2418
#
#    event_longitude cz_type  cz_fips_code  damage_crops             source
# 0         -75.7300       C             3           0.0  River/Stream Gage
# ...

# %%
flood_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34586 entries, 0 to 34585
# Data columns (total 13 columns):
# episode_id          34586 non-null int64
# state               34586 non-null object
# event_type          34586 non-null object
# event_begin_time    34586 non-null object
# event_end_time      34586 non-null object
# event_timezone      34586 non-null object
# damage_property     33519 non-null float64
# event_latitude      34586 non-null float64
# event_longitude     34586 non-null float64
# cz_type             34586 non-null object
# cz_fips_code        34586 non-null int64
# damage_crops        33053 non-null float64
# source              34586 non-null object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 3.4+ MB

# %%
flood_data[["Start_Date", "Start_Time"]] = flood_data.event_begin_time.str.split(" ", expand = True)
flood_data[["End_Date", "End_Time"]] = flood_data.event_end_time.str.split(" ", expand = True)

# %%
flood_data
# Out:
#        episode_id          state event_type     event_begin_time  \
# 0           59076       Delaware      flood  2012-01-12 05:50:00
# 1           59077     New jersey      flood  2012-01-12 10:27:00
# 2           59077     New jersey      flood  2012-01-12 11:50:00
# 3           59155        Indiana      flood  2012-01-17 23:45:00
# 4           59379        Alabama      flood  2012-01-26 19:00:00
# 5           59573      Louisiana      flood  2012-02-03 11:30:00
# 6           59659   Pennsylvania      flood  2012-01-27 05:01:00
# 7           59667         Oregon      flood  2012-01-19 10:31:00
# 8           59667         Oregon      flood  2012-01-19 20:31:00
# 9           59667         Oregon      flood  2012-01-19 08:55:00
# 10          59674         Oregon      flood  2012-01-19 11:30:00
# 11          59675           Ohio      flood  2012-01-27 01:00:00
# 12          59677         Oregon      flood  2012-01-19 11:45:00
# ...

# %%
flood_data.Start_Date = pd.to_datetime(flood_data.Start_Date)
flood_data.Start_Time = pd.to_datetime(flood_data.Start_Time)

# %%
flood_data.End_Date = pd.to_datetime(flood_data.End_Date)
flood_data.End_Time = pd.to_datetime(flood_data.End_Time)

# %%
new_flood = pd.DataFrame(flood_data)

# %%
new_flood.damage_crops.fillna(0, inplace = True)
new_flood.damage_property.fillna(0, inplace = True)

# %%
clean_floods = new_flood.to_csv(path_or_buf='floods_data.csv', index = False)
